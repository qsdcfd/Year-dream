# %% [markdown]
# # **데이터 크롤링**

# %% [markdown]
# ## **크롤링이란?**
# > 크롤러(crawler)는 자동화된 방법으로 웹을 탐색하는 컴퓨터 프로그램
# '웹 크롤링'(web crawling)??
# '데이터 크롤링'(data crawling)!!

# %% [markdown]
# 우리는 매일 크롤러도 사용하고 있습니다.

# %% [markdown]
# ## **웹 크롤링**
# > 웹 서비스 내 정보를 수집하는 일
#
# >> 필요한 정보가 있다면?
# API 확인 -> 없으면 직접 크롤링
#
# > 다만 서비스 제공자의 입장에서는?? 그렇게 달가운 것은 아니다.

# %% [markdown]
# ### 웹 서핑을 하는 의식의 흐름
# > - 브라우저 오픈
# > - 원하는 인터넷페이지 주소 입력
# > - 화면이 열리면 찾고자 하는 정보를 스크롤 하면서 찾기
# > - 문자, 그림, 동영상 조회

# %% [markdown]
# ### 웹 크롤링 하는 의식의 흐름
# > - 정보를 가져오고자 하는 url 정의
# > - url 정보로 requests로 정보 요청
# > - text 정보를 html로 변환 : html특성으로 비슷한 내용을 군집합 습성이용
# > - html에서 우리가 필요한 정보만 선별

# %% [markdown]
# ### 웹 크롤링을 위해 BeautifulSoup 사용
# > - requests는 요청을 받기는 하지만 text로만 받음
# > - API는 통신을 위해 정형화 된 데이터 형태의 text
# > - 우리가 원하는 데이터로 가공하기 위해 편의상 html로 변환
# > - text를 html로 변환하는 모듈이 beautifulSoup

# %% [markdown]
# ### 간단한 데이터 크롤링으로 기본 개념잡기

# %%
# 필요패키지 import
import numpy as np
import pandas as pd
import requests # 크롤링에 사용하는 패키지
from bs4 import BeautifulSoup # html 변환에 사용함

# %% [markdown]
# #### 네이버 메인페이지 크롤링

# %%
"""
정보를 가져오고자 하는 url 정의
url 정보로 requests로 정보 요청
text 정보를 html로 변환
html에서 우리가 필요한 정보만 선별
"""

# 네이버 메인페이지

# url정의(문자열 형식으로 전다르 https://포함 , www.생략가능)
url = 'https://www.naver.com'

# reqeusts로 url에 정보요청
#reqeusts 파이썬이 컴퓨터간 통신체계에 해당하는 명령어들을 사용하도록 만든 패키지
#해당코드를 실행시키는 순간 서비스 제공자에게 정보요청을 함.
resp = requests.get(url)

# 정보를 html 변환 (보기 쉽게)
html= BeautifulSoup(resp.text, 'html.parser')
# html 내에서 우리가 보고 싶은 정보만 선별
html.select('img')

# %% [markdown]
# #### 다음 뉴스페이지 크롤링

# %%
# 다음 뉴스 페이지 크롤링
# url정의
url = 'https://news.daum.net/'
# requsts로 url에 정보요청
resp = requests.get(url)
# 정보를 html 변환 (보기 쉽게)
html = BeautifulSoup(resp.text, 'html.parser')
# html 내에서 뉴스헤더 선별
for news in html.select('a.link_txt')[:32]:
    print(news.text.strip())
# Out:
# 국민대 연구윤리위, '김건희 논문 의혹' 재조사 결과 논의
# 냉전때 미·러 편들었는데..중립으로 돌아서는 개도국들
# 김오수 "박병석 면담서 검수완박 중재안의 '중'자도 못 들었다"
# 확진 급감 경기 4주새 사망  54.4%↓..3월4주 82명→4월4주 37명 '뚝'
# 마크롱, 20년만 첫 연임..역대 佛대통령 재선서 고배마신 이유는
# 日, '윤석열 특사단' 주목.."한일관계 개선안 내놓나"
# 이게 진짜 맛있니? '할매 입맛'에 250만개 팔린 과자
# "디지털혁신 책임질 과학기술수석비서관 설치해야"
# 충북 학생 확진 엿새째 급감..이틀째 20명 이내
# 최경식 남원시장 예비후보, 허위사실 피켓 시위자 검찰에 고발
# 문대통령, 코로나 백신 4차 접종 후 "많이 호응하셨으면"
# 김대중 전남교육감 후보, '교육 기본소득' 쟁점화
# 檢서열 3위도 '검수완박' 반대.."가진 자들 비리 넘쳐날 것"
# "5,6,7월 금리 0.5%씩 뛴다?" 이자 쇼크가 온다..코스피 '긴축 공포'
# 인수위, 내연기관차 퇴출 시점 못 안 박는다
# 국내 최초 반려견 동반 극장 가보니..개들의 관람 매너가 사람보다 좋았다
# 윤석열 "가을이나 내년 봄 한-미 야외기동훈련 재개"
# 年 1조원 넘는 통신비 감면액.. 통신복지 개편 논의 탄력받나
# '뛰는 휘발유 위에 나는 경유'..제주서 가격 역전
# 윤당선인 '3대공약'.. 돌려막기 예산확보 비상
# [뉴스1 PICK]김오수 "검수완박 중재안 동의 못 해..국민이 원치 않을 것"
# [오마이포토] '민주·정의 불참' 한덕수 인사청문회 반쪽 개의
# 균형발전 강조하지만..2기 GTX 등 수도권에 교통투자 집중 [강갑생의 바퀴와 날개]
# [지구촌 돋보기] 세계 펭귄의 날
# 中 "왜 미국만 지구를 구해? 우리도 한다!"[과학을읽다]
# [현장영상+] 김오수 "중재안, 검수완박 시행시기만 잠시 늦춘 것에 불과"
# [뉴스라이브] 이준석 "검수완박 합의 재검토"..'뒤집기' 시도?
# ...

# %%
html.select('a.link_txt')[0].text.strip()
# Out:
# "국민대 연구윤리위, '김건희 논문 의혹' 재조사 결과 논의"

# %%
for news in html.select('a.link_txt')[:32]:
    print(news.text.strip())
# Out:
# 국민대 연구윤리위, '김건희 논문 의혹' 재조사 결과 논의
# 냉전때 미·러 편들었는데..중립으로 돌아서는 개도국들
# 김오수 "박병석 면담서 검수완박 중재안의 '중'자도 못 들었다"
# 확진 급감 경기 4주새 사망  54.4%↓..3월4주 82명→4월4주 37명 '뚝'
# 마크롱, 20년만 첫 연임..역대 佛대통령 재선서 고배마신 이유는
# 日, '윤석열 특사단' 주목.."한일관계 개선안 내놓나"
# 이게 진짜 맛있니? '할매 입맛'에 250만개 팔린 과자
# "디지털혁신 책임질 과학기술수석비서관 설치해야"
# 충북 학생 확진 엿새째 급감..이틀째 20명 이내
# 최경식 남원시장 예비후보, 허위사실 피켓 시위자 검찰에 고발
# 문대통령, 코로나 백신 4차 접종 후 "많이 호응하셨으면"
# 김대중 전남교육감 후보, '교육 기본소득' 쟁점화
# 檢서열 3위도 '검수완박' 반대.."가진 자들 비리 넘쳐날 것"
# "5,6,7월 금리 0.5%씩 뛴다?" 이자 쇼크가 온다..코스피 '긴축 공포'
# 인수위, 내연기관차 퇴출 시점 못 안 박는다
# 국내 최초 반려견 동반 극장 가보니..개들의 관람 매너가 사람보다 좋았다
# 윤석열 "가을이나 내년 봄 한-미 야외기동훈련 재개"
# 年 1조원 넘는 통신비 감면액.. 통신복지 개편 논의 탄력받나
# '뛰는 휘발유 위에 나는 경유'..제주서 가격 역전
# 윤당선인 '3대공약'.. 돌려막기 예산확보 비상
# [뉴스1 PICK]김오수 "검수완박 중재안 동의 못 해..국민이 원치 않을 것"
# [오마이포토] '민주·정의 불참' 한덕수 인사청문회 반쪽 개의
# 균형발전 강조하지만..2기 GTX 등 수도권에 교통투자 집중 [강갑생의 바퀴와 날개]
# [지구촌 돋보기] 세계 펭귄의 날
# 中 "왜 미국만 지구를 구해? 우리도 한다!"[과학을읽다]
# [현장영상+] 김오수 "중재안, 검수완박 시행시기만 잠시 늦춘 것에 불과"
# [뉴스라이브] 이준석 "검수완박 합의 재검토"..'뒤집기' 시도?
# ...

# %%
for news in html.select('a.link_txt')[:32]:
    print(news.text.strip().replace('[','').replace(']',''))
# Out:
# 국민대 연구윤리위, '김건희 논문 의혹' 재조사 결과 논의
# 냉전때 미·러 편들었는데..중립으로 돌아서는 개도국들
# 김오수 "박병석 면담서 검수완박 중재안의 '중'자도 못 들었다"
# 확진 급감 경기 4주새 사망  54.4%↓..3월4주 82명→4월4주 37명 '뚝'
# 마크롱, 20년만 첫 연임..역대 佛대통령 재선서 고배마신 이유는
# 日, '윤석열 특사단' 주목.."한일관계 개선안 내놓나"
# 이게 진짜 맛있니? '할매 입맛'에 250만개 팔린 과자
# "디지털혁신 책임질 과학기술수석비서관 설치해야"
# 충북 학생 확진 엿새째 급감..이틀째 20명 이내
# 최경식 남원시장 예비후보, 허위사실 피켓 시위자 검찰에 고발
# 문대통령, 코로나 백신 4차 접종 후 "많이 호응하셨으면"
# 김대중 전남교육감 후보, '교육 기본소득' 쟁점화
# 檢서열 3위도 '검수완박' 반대.."가진 자들 비리 넘쳐날 것"
# "5,6,7월 금리 0.5%씩 뛴다?" 이자 쇼크가 온다..코스피 '긴축 공포'
# 인수위, 내연기관차 퇴출 시점 못 안 박는다
# 국내 최초 반려견 동반 극장 가보니..개들의 관람 매너가 사람보다 좋았다
# 윤석열 "가을이나 내년 봄 한-미 야외기동훈련 재개"
# 年 1조원 넘는 통신비 감면액.. 통신복지 개편 논의 탄력받나
# '뛰는 휘발유 위에 나는 경유'..제주서 가격 역전
# 윤당선인 '3대공약'.. 돌려막기 예산확보 비상
# 뉴스1 PICK김오수 "검수완박 중재안 동의 못 해..국민이 원치 않을 것"
# 오마이포토 '민주·정의 불참' 한덕수 인사청문회 반쪽 개의
# 균형발전 강조하지만..2기 GTX 등 수도권에 교통투자 집중 강갑생의 바퀴와 날개
# 지구촌 돋보기 세계 펭귄의 날
# 中 "왜 미국만 지구를 구해? 우리도 한다!"과학을읽다
# 현장영상+ 김오수 "중재안, 검수완박 시행시기만 잠시 늦춘 것에 불과"
# 뉴스라이브 이준석 "검수완박 합의 재검토"..'뒤집기' 시도?
# ...

# %%
#다음에서 로또 번호 혹은 로또로 검색해서 표시되는 로또번호 크롤링
url = "https://search.daum.net/search?w=tot&DA=YZR&t__nil_searchbox=btn&sug=&sugo=&sq=&o=&q=%EB%A1%9C%EB%98%90%EB%B2%88%ED%98%B8"
# reqeusts로 url에 정보요청

resp = requests.get(url)

# 정보를 html 변환 (보기 쉽게)
html= BeautifulSoup(resp.text, 'html.parser')
# html 내에서 우리가 보고 싶은 정보만 선별

# %%
html
# Out:
# <!DOCTYPE html>
#
# <html class="unix unknown" lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head profile="http://a9.com/-/spec/opensearch/1.1/">
# <meta content="text/html;charset=utf-8" http-equiv="content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="off" name="autocomplete"/>
# <meta content="always" name="referrer"/>
# <meta content="telephone=no" name="format-detection">
# <meta content="로또번호 – Daum 검색" property="og:title"/>
# <meta content="https://search.daum.net/search?w=tot&amp;q=%EB%A1%9C%EB%98%90%EB%B2%88%ED%98%B8" property="og:url"/>
# <meta content="Daum 검색에서 로또번호에 대한 최신정보를 찾아보세요." property="og:description"/>
# <meta content="https://search1.daumcdn.net/search/statics/common/img/og_search.png" property="og:image"/>
# <meta content="다음검색" property="og:site_name"/>
# <title>로또번호 – Daum 검색</title>
# <link href="//search.daum.net/OpenSearch.xml" rel="search" title="Daum" type="application/opensearchdescription+xml"/>
# ...

# %%
html.select('div.wrap_lotto')
# Out:
# [<div class="wrap_lotto"> <div class="lottonum"> <span class="ball bg_ball1">5</span> <span class="ball bg_ball2">11</span> <span class="ball bg_ball2">18</span> <span class="ball bg_ball2">20</span> <span class="ball bg_ball4">35</span> <span class="ball bg_ball5">45</span> <span class="ball txt_bonus"><span class="screen_out">보너스</span></span> <span class="ball bg_ball1">3</span> </div> <a class="btn_compr_l" href="https://www.dhlottery.co.kr/gameResult.do?method=myWin" onclick='smartLog(this, "s=TO&amp;a=LOTT&amp;pg=1&amp;r=1&amp;rc=1&amp;p=4&amp;e=&amp;dc=LOT&amp;d=1012&amp;at=", event);' target="_blank"><span class="inner">내번호 당첨조회</span></a> </div>]

# %%
for ball_nm in

# %% [markdown]
# ### 실제 개발자가 작성한 코드로 확인된다
# > 정제되지 않은 데이터로 가독성이 좋지 않음
# 우리는 이 중에서 우리가 원하는 정보를 선별해서 가져오는 작업을 진행합니다.
# 그러기에 html의 기본 구성을 살펴보도록 하겠습니다.

# %% [markdown]
# #### 웹 페이지의 구성
# > **HTML(Hyper Text Markup Language)**
# www 를 구성하는데 사용하는 국제표준 언어로서 컨텐츠와 레이아웃을 담고 있다
#
# > **<태그>** 내용 **</태그>**
# <tag이름 class="class이름1 class이름2" id="주민번호" href="주소"></tag이름>
#
# > 형태나 속성을 묘사하기 위한 구조적 언어 : HTML, CSS (계층이 있음)
# 웹의 작동 및 제어를 위한 프로그래밍 언어 :  Js

# %% [markdown]
# #### 셀렉터
# > 용도 : html에서 내가 원하는 내용을 찾아내기 위해서
# <span class="news" id="1234">비비고 왕교자</span>
# <span class="product" id="1235">비비고 볶음밥</span>
#
# class: 품목, id = 상세 번호(고유값), 그 다음은 상품 제목
#
# >> 단일 셀렉터
# html.select('span')  # 태그 이름이 span인 친구들을 다 들고옴
# tag : span
# class(별명, 그룹명) : .news
#
# >> 클래스 포함 셀렉터
# html.select('span.news')
#
# >> id 포함 셀렉터
# id(고유값) : #1234
# html.select('span#1234')

# %% [markdown]
# #### 복합 셀렉터
#     1. 조합 셀렉터
#     <span>1</span>
#     <span class="txt">2</span>
#     <em class="txt">3</em>
#
#     태그 이름이 span이고 클래스 이름은 txt인 라인을 찾고 싶다. : span.txt
#     em 태그 중에서 class가 text 인 라인을 찾고\ 싶다. : em.text
#
#     2. 경로 셀렉터
#
#     <span>이걸 찾으려면?</span>
#     <span>이걸 찾으려면?</span>
#     <span>이걸 찾으려면?</span>
#     <ul>
#         <li><span>이걸 찾으려면?</span></li>
#     </ul>
#     <span>이건 아님</span>
#
#     ul 태그안 li 태그 안 span 라인을 찾는다
#     ul > li > span 혹은 ul li span

# %%
import time

# %%
key_list = ['슬기로운의사생활', '도깨비', '오징어게임']
for item in key_list:
    print(item)
# Out:
# 슬기로운의사생활
# 도깨비
# 오징어게임

# %%
#슬의생, 도깨비, 오징어게임
#드라마 하나 정해서 크롤링 완료된 것을 확인하고 슬의생, 도깨비, 오징어게임 리스트 만들어서 확인
# 슬의생 드라마소개 크롤링


key_list = ['슬기로운의사생활', '도깨비', '오징어게임']
keys_list = []
for key_word in key_list:
    time.sleep(2)
    url=f'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query={key_word}'
    
    #정보 요청
    resp = requests.get(url)

    # 정보를 html 변환 (보기 쉽게)
    html= BeautifulSoup(resp.text, 'html.parser')

    # html 내에서 우리가 보고 싶은 정보만 선별
    keys_list.append(html.select('span.desc._text')[0].text)
# Out:
# ['누군가는 태어나고 누군가는 삶을 끝내는, 인생의 축소판이라 불리는 병원에서 평범한 듯 특별한 하루하루를 살아가는 사람들과 눈빛만 봐도 알 수 있는 20년지기 친구들의 케미스토리를 담은 드라마', "불멸의 삶을 끝내기 위해 인간 신부가 필요한 도깨비, 그와 기묘한 동거를 시작한 기억상실증 저승사자. 그런 그들 앞에 '도깨비 신부'라 주장하는 '죽었어야 할 운명'의 소녀가 나타나며 벌어지는 신비로운 낭만 설화", '456억 원의 상금이 걸린 의문의 서바이벌에 참가한 사람들이 최후의 승자가 되기 위해 목숨을 걸고 극한의 게임에 도전하는 이야기를 담은 넷플릭스 시리즈']

# %%
for i in range(3):
    print(key_list[i], keys_list[i].split('\n'))
# Out:
# 슬기로운의사생활 ['누군가는 태어나고 누군가는 삶을 끝내는, 인생의 축소판이라 불리는 병원에서 평범한 듯 특별한 하루하루를 살아가는 사람들과 눈빛만 봐도 알 수 있는 20년지기 친구들의 케미스토리를 담은 드라마']
# 도깨비 ["불멸의 삶을 끝내기 위해 인간 신부가 필요한 도깨비, 그와 기묘한 동거를 시작한 기억상실증 저승사자. 그런 그들 앞에 '도깨비 신부'라 주장하는 '죽었어야 할 운명'의 소녀가 나타나며 벌어지는 신비로운 낭만 설화"]
# 오징어게임 ['456억 원의 상금이 걸린 의문의 서바이벌에 참가한 사람들이 최후의 승자가 되기 위해 목숨을 걸고 극한의 게임에 도전하는 이야기를 담은 넷플릭스 시리즈']

# %%
# 해당 드라마 뉴스 제목 크롤링

# %% [markdown]
# ## 다음에서 로또번호 가져와 볼께요 몽땅 다 가져옵니다(30페이지)

# %%
# url 설정

# requests로 데이터 요청하기

# html로 변환

# 데이터 선별

# %%
# 차단막는 코드
seed = np.random.randint(100)
np.random.seed(seed)
a = np.random.randint(5)
time.sleep(a)

# %%
key_list =[]
for key_word in range(1,31):
    print(f'{key_word}회차 크롤링 중입니다.')
    seed = np.random.randint(100)
    np.random.seed(seed)
    a = np.random.randint(5)
    time.sleep(a)
    

    #다음에서 로또 번호 혹은 로또로 검색해서 표시되는 로또번호 크롤링
    url = f"https://search.daum.net/search?w=tot&DA=LOT&rtmaxcoll=LOT&&q={key_word}회차%로또"
    # reqeusts로 url에 정보요청

    resp = requests.get(url)

    # 정보를 html 변환 (보기 쉽게)
    html= BeautifulSoup(resp.text, 'html.parser')
    key_list.append(html.select('div.wrap_lotto'))
    
print(key_list)
# Out:
# 1회차 크롤링 중입니다.
# 2회차 크롤링 중입니다.
# 3회차 크롤링 중입니다.
# 4회차 크롤링 중입니다.
# 5회차 크롤링 중입니다.
# 6회차 크롤링 중입니다.
# 7회차 크롤링 중입니다.
# 8회차 크롤링 중입니다.
# 9회차 크롤링 중입니다.
# 10회차 크롤링 중입니다.
# 11회차 크롤링 중입니다.
# 12회차 크롤링 중입니다.
# 13회차 크롤링 중입니다.
# 14회차 크롤링 중입니다.
# 15회차 크롤링 중입니다.
# 16회차 크롤링 중입니다.
# 17회차 크롤링 중입니다.
# 18회차 크롤링 중입니다.
# 19회차 크롤링 중입니다.
# 20회차 크롤링 중입니다.
# 21회차 크롤링 중입니다.
# 22회차 크롤링 중입니다.
# 23회차 크롤링 중입니다.
# 24회차 크롤링 중입니다.
# 25회차 크롤링 중입니다.
# 26회차 크롤링 중입니다.
# 27회차 크롤링 중입니다.
# 28회차 크롤링 중입니다.
# 29회차 크롤링 중입니다.
# 30회차 크롤링 중입니다.
# ...

# %%
lotto_list = []
for i in range(1,31):
    print(f'{i}회차 크롤링 중입니다.')
    seed = np.random.randint(100)
    np.random.seed(seed)
    a = np.random.randint(5)
    time.sleep(a)
    #url
    url = f"https://search.daum.net/search?w=tot&DA=LOT&rtmaxcoll=LOT&&q={i}회차%로또"
    #requests로 데이터 요청하기
    resp = requests.get(url)

    # 정보를 html 변환 (보기 쉽게)
    html= BeautifulSoup(resp.text, 'html.parser')
    
    #데이터 선별
    for ball_nm in html.select('span.ball')[:6]:
        lotto_list.append(int(ball_nm.text))

print('크롤링 완료')
# Out:
# 1회차 크롤링 중입니다.
# 2회차 크롤링 중입니다.
# 3회차 크롤링 중입니다.
# 4회차 크롤링 중입니다.
# 5회차 크롤링 중입니다.
# 6회차 크롤링 중입니다.
# 7회차 크롤링 중입니다.
# 8회차 크롤링 중입니다.
# 9회차 크롤링 중입니다.
# 10회차 크롤링 중입니다.
# 11회차 크롤링 중입니다.
# 12회차 크롤링 중입니다.
# 13회차 크롤링 중입니다.
# 14회차 크롤링 중입니다.
# 15회차 크롤링 중입니다.
# 16회차 크롤링 중입니다.
# 17회차 크롤링 중입니다.
# 18회차 크롤링 중입니다.
# 19회차 크롤링 중입니다.
# 20회차 크롤링 중입니다.
# 21회차 크롤링 중입니다.
# 22회차 크롤링 중입니다.
# 23회차 크롤링 중입니다.
# 24회차 크롤링 중입니다.
# 25회차 크롤링 중입니다.
# 26회차 크롤링 중입니다.
# 27회차 크롤링 중입니다.
# 28회차 크롤링 중입니다.
# 29회차 크롤링 중입니다.
# 30회차 크롤링 중입니다.
# 크롤링 완료

# %%
lotto = np.array(lotto_list).reshape(-1,6)

# %%
index = [f'{i}회차'for i in range(1,31)]

# %%
df = pd.DataFrame(lotto,
                 index=index)

df
# Out:
#        0   1   2   3   4   5
# 1회차   10  23  29  33  37  40
# 2회차    9  13  21  25  32  42
# 3회차   11  16  19  21  27  31
# 4회차   14  27  30  31  40  42
# 5회차   16  24  29  40  41  42
# 6회차   14  15  26  27  40  42
# 7회차    2   9  16  25  26  40
# 8회차    8  19  25  34  37  39
# 9회차    2   4  16  17  36  39
# 10회차   9  25  30  33  41  44
# 11회차   1   7  36  37  41  42
# 12회차   2  11  21  25  39  45
# 13회차  22  23  25  37  38  42
# 14회차   2   6  12  31  33  40
# 15회차   3   4  16  30  31  37
# 16회차   6   7  24  37  38  40
# 17회차   3   4   9  17  32  37
# 18회차   3  12  13  19  32  35
# 19회차   6  30  38  39  40  43
# 20회차  10  14  18  20  23  30
# 21회차   6  12  17  18  31  32
# 22회차   4   5   6   8  17  39
# 23회차   5  13  17  18  33  42
# 24회차   7   8  27  29  36  43
# 25회차   2   4  21  26  43  44
# 26회차   4   5   7  18  20  25
# 27회차   1  20  26  28  37  43
# 28회차   9  18  23  25  35  37
# 29회차   1   5  13  34  39  40
# 30회차   8  17  20  35  36  44

# %%
# 데이터 시각화까지
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
sns.countplot(lotto_list)
# Out:
# /Users/krc/miniforge3/envs/krc/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
# 로또데이터 저장

# %%
requests.codes.ok
# 100 우리 이런정보 내주는거야
# 200 성공
# 300 우리 이 사이트 이리루 이사했어 일루가
# 400 유저가 요청을 잘못한경우
# 500 서버 문제
# Out:
# 200

# %%
# 차단막는 코드
seed = np.random.randint(100)
np.random.seed(seed)
a = np.random.randint(5)
time.sleep(a)

# %%
for item in html.select('span.ball'):
    print(item.text)
# Out:
# 8
# 17
# 20
# 35
# 36
# 44
# 보너스
# 4

# %% [markdown]
# ## **네이버 키워드로 검색한 결과를 크롤링(속성 접근)**

# %%
key_word = input("키워드를 입력하세요:")

url = f'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query={key_word}'
# requsts로 url에 정보요청
resp = requests.get(url)
# 정보를 html 변환 (보기 쉽게)
html = BeautifulSoup(resp.text, 'html.parser')
# Out:
# 키워드를 입력하세요:이어드림스쿨

# %%
html
# Out:
# <!DOCTYPE html>
# ...

# %%
# html 내에서 뉴스헤더 선별
for news in html.select('a.api_txt_lines'): #api_txt_lines, total_tit, _cross_trigger,리스트 형식
        print(news.text, news.attrs['href'])#하이퍼 링크얻음
# Out:
# 스타트업 AI기술인력 양성(이어드림 스쿨) 교육운영사 모집 공고_중소벤처기업부 https://blog.naver.com/ash1106/222630166306
# 2022년 스타트업 AI기술인력 양성사업(이어드림 스쿨) 청년인재 모집 연장 공고 https://blog.naver.com/sdhys2/222654360952
# 중진공, 이어드림 스쿨(Year Dream School)을 소개합니다! https://blog.naver.com/sbcblog/222596245344
# 이어드림스쿨 면접 후기 https://blog.naver.com/lrickyl/222676324522
# 2022년 스타트업 AI기술인력 양성(이어드림 스쿨) 2기 교육생 모집 https://blog.naver.com/neetpeace12/222654614810
# 이어드림스쿨 어떨까요? AI교육(8개월) 현실적으로 어떨까요... https://cafe.naver.com/dokchi/11615964?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtY2FmZS1wcg.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImRva2NoaSIsImFydGljbGVJZCI6MTE2MTU5NjQsImlzc3VlZEF0IjoxNjUwODY0MjI4NjEyfQ.YVY4VMhKEDWCXyTHESUz-bThfznQcVkoB-qn9ai3Uh4
# 2022년 스타트업 AI기술인력 양성사업(이어드림 스쿨) 청년인재 모집공고 [출처- k startup] https://blog.naver.com/sosang0inshop/222625838801
# [지원사업 공고][22.02.18]2022년 스타트업 AI기술인력 양성사업(이어드림 스쿨) 청년인재 모집공고 https://blog.naver.com/linkedkorea/222638508397
# ...

# %%
# Out:
# 키워드를 입력하세요 :세탁기
# 설치까지 완벽한 위닉스 세탁기건조기 환영해 https://blog.naver.com/dngusghk/222470214924
# LG 트윈워시 드럼세탁기 분해 청소 비용, 가격 및 후기 https://blog.naver.com/aejiniyam/222473577816
# 드럼세탁기세탁조클리너 아직도 안써봄? https://blog.naver.com/marianne40/222503916107
# 김포세탁기청소 퀴퀴한 냄새 제거하기 https://blog.naver.com/totos1207/222478318008
# 세탁기통세척 이젠 상쾌한 향만~ https://cafe.naver.com/ungsangjang/414104
# 이사하시나요? 세탁기 냉장고등 가전이 필요하신가요? https://adcr.naver.com/adcr?x=+xSggTaUcCgQ0eFc2ofgF////w==...
# 세탁기렌탈 사는거보다 훨씬 싸게 장만한 후기! https://adcr.naver.com/adcr?x=zVZE5iC+R+KaPSRZc3U6Of///w==...
# 세탁기 이물질 세탁기 2년 안됬는데 최근들어 계속 먼지랑 같이 이물질이 나와요 ㅠㅠ 먼지망도 청소 해보고 무세제 통세척도 해봤는데 먼지망에도 쌓이고 흰옷에도 계속 묻어나와요 어떻게해야될까요?? https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80903&docId=398932087&qb=7IS47YOB6riw&enc=utf8§ion=kin.ext&rank=1&search_sort=0&spq=0
# ...

# %% [markdown]
#     가져온 데이터에 접근을 하는 방식 자체는 판다스 색인처럼 결과값을 확인하며 진행하는 것이 가장 좋습니다.

# %% [markdown]
# #### 관심있는 개별종목의 시가총액, 외국인 소진률, PER, PBR 가져오기

# %%
key_list = ['슬기로운의사생활', '도깨비', '오징어게임']
keys_list = []
for key_word in key_list:
    time.sleep(2)
    url=f'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query={key_word}'
    
    #정보 요청
    resp = requests.get(url)

    # 정보를 html 변환 (보기 쉽게)
    html= BeautifulSoup(resp.text, 'html.parser')

    # html 내에서 우리가 보고 싶은 정보만 선별
    keys_list.append(html.select('span.desc._text')[0].text)

# %%
code = input('종목코드를 입력하세요:')

url = f'https://finance.naver.com/item/main.nhn?code={code}'
# reqeusts로 url에 정보요청

resp = requests.get(url)

# 정보를 html 변환 (보기 쉽게)
html= BeautifulSoup(resp.text, 'html.parser')
# Out:
# 종목코드를 입력하세요:000660

# %%
html
# Out:
# <html lang="ko">
# <head>
# <title>SK하이닉스 : 네이버 금융</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="https://finance.naver.com/item/main.naver?code=000660" property="og:url">
# <meta content="SK하이닉스 - 네이버 금융 : 네이버 금융" property="og:title">
# <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버금융" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220407160311/css/finance_header.css" rel="stylesheet" type="text/css"/>
# ...

# %%
#딕셔너리
{종목명: 코드}
{코드: 종목명}

# %%
# html 내에서 우리가 보고 싶은 정보만 선별
#시가총액

html.select('em#_market_sum')[0].text.replace('\n','').replace('\t','')#시가총액
# Out:
# '78조6,243'

# %%
#외국인 소진율

html.select('tr.strong em')[1].text
# Out:
# '49.87%'

# %%
#PER
html.select('#_per')[0].text
# Out:
# '8.19'

# %%
#PBR
html.select('#_pbr')[0].text
# Out:
# '1.19'

# %%
#종목명
html.select('div.wrap_company a')[0].text
# Out:
# 'SK하이닉스'

# %%
# url 정의

# requests 요청

# html 변환

# 시가총액, 외국인 소진률, PER, PBR

# %% [markdown]
# #### 여러 종목의 시가총액, 외국인 소진률, PER, PBR 한꺼번에 가져오기

# %%
# 종목리스트 정의

# url 정의

# requests 요청

# html 변환

# 데이터 선별
# Out:
# 005930 크롤링 중입니다.
# 002020 크롤링 중입니다.
# 323410 크롤링 중입니다.
# 크롤링 종료

# %%
code_list=[]
code = ['005930','002020','323410']
for i in code:
    print(f'{i} 크롤링 중입니다.')
    seed = np.random.randint(100)
    np.random.seed(seed)
    a = np.random.randint(5)
    time.sleep(a)
    #url
    url = f"https://finance.naver.com/item/main.nhn?code={i}"
    #requests로 데이터 요청하기
    resp = requests.get(url)

    # 정보를 html 변환 (보기 쉽게)
    html= BeautifulSoup(resp.text, 'html.parser')
    
    #데이터 선별
    
    code_list.append(html.select('div.wrap_company a')[0].text)#종목명
    code_list.append(html.select('em#_market_sum')[0].text.replace('\n','').replace('\t',''))#시가총액
    code_list.append(html.select('tr.strong em')[1].text)#외국인 소진율
    code_list.append(html.select('#_per')[0].text)#PER
    code_list.append(html.select('#_pbr')[0].text)#PBR
    
print('크롤링 완료')
# Out:
# 005930 크롤링 중입니다.
# 002020 크롤링 중입니다.
# 323410 크롤링 중입니다.
# 크롤링 완료

# %%
codes = np.array(code_list).reshape(-1,5)

# %%
index = [f'{i}'for i in ['005930','002020','323410']]

# %%
df = pd.DataFrame(codes,
                 index=index)

df
# Out:
#             0          1       2      3     4
# 005930   삼성전자  395조7,966  51.13%  11.48  1.52
# 002020    코오롱      3,561  10.70%   2.78  0.44
# 323410  카카오뱅크   20조2,145  15.80%  90.90  3.65

# %%
df.columns = ['종목명','시가총액','외국인소진률','PER','PBR']
df
# Out:
#           종목명       시가총액  외국인소진률    PER   PBR
# 005930   삼성전자  395조7,966  51.13%  11.48  1.52
# 002020    코오롱      3,561  10.70%   2.78  0.44
# 323410  카카오뱅크   20조2,145  15.80%  90.90  3.65

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
sns.countplot(code_list)

# %% [markdown]
# ## **동적페이지 크롤링**
# > 최근에는 Js로 변경이 되며 일반적인 크롤링이 되지 않는 경우가 많음
# 동적페이지와 숨겨진 url을 가져오는 방법을 알아봅니다

# %% [markdown]
# ### 네이버 주식 시세 데이터 크롤링

# %%
url = 'https://finance.naver.com/item/sise_day.naver?code=000660&page=2'

info = {
    'referer': 'https://finance.naver.com/item/sise_day.naver?code=000660&page=1',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Mobile Safari/537.36'
}

# %%
resp = requests.get(url, headers=info)

# %%
html = BeautifulSoup(resp.text, 'html.parser')

# %%
html
# Out:
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>네이버 금융</title>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220407160311/css/newstock.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220407160311/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220407160311/css/layout.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220407160311/css/main.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220407160311/css/newstock2.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220407160311/css/newstock3.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20220407160311/css/world.css" rel="stylesheet" type="text/css"/>
# </head>
# ...

# %%
#컬럼명 설렉트
col_nm = [col.text for col in html.select('th')[1:]]
col_nm
# Out:
# ['종가', '전일비', '시가', '고가', '저가', '거래량']

# %%
#날짜 설렉트
index = [date.text for date in html.select('span.gray03')] # tah p10 gray03 :날짜
index
# Out:
# ['2022.04.11',
#  '2022.04.08',
#  '2022.04.07',
#  '2022.04.06',
#  '2022.04.05',
#  '2022.04.04',
#  '2022.04.01',
#  '2022.03.31',
#  '2022.03.30',
#  '2022.03.29']

# %%
#가격정보 설렉트
prices = [price.text.strip() for price in html.select('span.p11')]#tag p11
prices
# Out:
# ['111,500',
#  '500',
#  '111,000',
#  '113,000',
#  '110,500',
#  '2,390,786',
#  '112,000',
#  '1,500',
#  '113,000',
#  '114,000',
#  '110,500',
#  '4,268,316',
#  '113,500',
#  '500',
#  '111,500',
#  '114,500',
#  '110,500',
#  '5,027,865',
#  '113,000',
#  '3,500',
#  '114,500',
#  '115,500',
#  '113,000',
#  '4,541,938',
#  '116,500',
#  '500',
#  '117,500',
#  '118,000',
#  '116,000',
#  '2,101,474',
#  '117,000',
#  '1,000',
#  '115,000',
#  '117,500',
#  '114,500',
#  '2,470,792',
#  '116,000',
#  '2,000',
#  '117,000',
#  '117,500',
#  '116,000',
#  '3,851,558',
#  '118,000',
#  '3,000',
#  '119,500',
#  '120,000',
#  '117,500',
#  '4,558,063',
#  '121,000',
#  '1,000',
#  '123,000',
#  '123,000',
#  '120,500',
#  '3,436,282',
#  '120,000',
#  '2,000',
#  '119,500',
#  '120,500',
#  '118,500',
#  '3,375,247']

# %%
prices = np.array(prices).reshape(-1,6)
prices
# Out:
# array([['111,500', '500', '111,000', '113,000', '110,500', '2,390,786'],
#        ['112,000', '1,500', '113,000', '114,000', '110,500', '4,268,316'],
#        ['113,500', '500', '111,500', '114,500', '110,500', '5,027,865'],
#        ['113,000', '3,500', '114,500', '115,500', '113,000', '4,541,938'],
#        ['116,500', '500', '117,500', '118,000', '116,000', '2,101,474'],
#        ['117,000', '1,000', '115,000', '117,500', '114,500', '2,470,792'],
#        ['116,000', '2,000', '117,000', '117,500', '116,000', '3,851,558'],
#        ['118,000', '3,000', '119,500', '120,000', '117,500', '4,558,063'],
#        ['121,000', '1,000', '123,000', '123,000', '120,500', '3,436,282'],
#        ['120,000', '2,000', '119,500', '120,500', '118,500', '3,375,247']],
#       dtype='<U9')

# %%
data = pd.DataFrame(prices,
                 columns = col_nm,
                 index=index)
data
# Out:
#                  종가    전일비       시가       고가       저가        거래량
# 2022.04.11  111,500    500  111,000  113,000  110,500  2,390,786
# 2022.04.08  112,000  1,500  113,000  114,000  110,500  4,268,316
# 2022.04.07  113,500    500  111,500  114,500  110,500  5,027,865
# 2022.04.06  113,000  3,500  114,500  115,500  113,000  4,541,938
# 2022.04.05  116,500    500  117,500  118,000  116,000  2,101,474
# 2022.04.04  117,000  1,000  115,000  117,500  114,500  2,470,792
# 2022.04.01  116,000  2,000  117,000  117,500  116,000  3,851,558
# 2022.03.31  118,000  3,000  119,500  120,000  117,500  4,558,063
# 2022.03.30  121,000  1,000  123,000  123,000  120,500  3,436,282
# 2022.03.29  120,000  2,000  119,500  120,500  118,500  3,375,247

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = data
df.head(5)
# Out:
#                  종가    전일비       시가       고가       저가        거래량
# 2022.04.11  111,500    500  111,000  113,000  110,500  2,390,786
# 2022.04.08  112,000  1,500  113,000  114,000  110,500  4,268,316
# 2022.04.07  113,500    500  111,500  114,500  110,500  5,027,865
# 2022.04.06  113,000  3,500  114,500  115,500  113,000  4,541,938
# 2022.04.05  116,500    500  117,500  118,000  116,000  2,101,474

# %%
def make_int(x):
    return int(x.replace(',', ''))

# %%
df['종가'] = df['종가'].apply(make_int)

# %%
plt.figure(figsize=(20,6))
plt.plot(df['종가'].sort_index())
plt.show()

# %% [markdown]
# ## 복습

# %%
name = []
for j in range(0,7):
    name.append(html.select('tr th')[j].text)
print(name)
# Out:
# ['날짜', '종가', '전일비', '시가', '고가', '저가', '거래량']

# %%
list_value = []
for i in range(0,6):
    list_value.append(html.select('tr td.num')[i].text.replace('\n',"").replace('\t',''))
    
print(list_value)
# Out:
# ['111,500', '500', '111,000', '113,000', '110,500', '2,390,786']

# %%
# 콤마 제거

# 함수 적용

# 타입 변환

# 종가 그래프

# %% [markdown]
# ### 20페이지 주가 정보 크롤링 해서 종가 그래프 출력

# %%
# 헤더정보 정의(동적페이지 헤더정보 그대로 사용)

# 인덱스 정의


# 전체 가격 데이터 빈 데이터 프레임

# requests 요청시에 헤더정보 추가

# html 변환

# 날짜 인덱스 살려서 활용하기

# 가격정보 추출

# 데이터프레임 제작
# Out:
# 1페이지 크롤링 중
# 2페이지 크롤링 중
# 3페이지 크롤링 중
# 4페이지 크롤링 중
# 5페이지 크롤링 중
# 6페이지 크롤링 중
# 7페이지 크롤링 중
# 8페이지 크롤링 중
# 9페이지 크롤링 중
# 10페이지 크롤링 중
# 11페이지 크롤링 중
# 12페이지 크롤링 중
# 13페이지 크롤링 중
# 14페이지 크롤링 중
# 15페이지 크롤링 중
# 16페이지 크롤링 중
# 17페이지 크롤링 중
# 18페이지 크롤링 중
# 19페이지 크롤링 중
# 20페이지 크롤링 중

# %% [markdown]
# ### 종목도 여러개 순환시키고 각 개별종목 데이터 csv 저장하는 연습

# %% [markdown]
# ### 네이버 데이터랩 인기검색어 크롤링

# %%
# json 데이터 파싱for key_word in key_list:

url='https://m.datalab.naver.com/shoppingInsight/getCategory.naver?cid=50000805'#키워드 랭크 사이트 찾기

info = {
    'referer': 'https://datalab.naver.com/',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Mobile Safari/537.36'

}

# %%
    #정보 요청
resp = requests.post(url, headers=info)

# %%
resp.text
# Out:
# '{"cid":50000805,"pid":50000167,"name":"니트/스웨터","parentPath":"패션의류 > 여성의류","level":3,"expsOrder":1,"parents":[{"cid":0,"name":"전체"},{"cid":50000000,"name":"패션의류"},{"cid":50000167,"name":"여성의류"}],"childList":[],"leaf":true,"deleted":false,"svcUse":true,"sblogUse":true,"fullPath":"패션의류 > 여성의류 > 니트/스웨터"}'

# %%
import json

# %%
data = json.loads(resp.text)

# %%
data
# Out:
# {'cid': 50000805,
#  'pid': 50000167,
#  'name': '니트/스웨터',
#  'parentPath': '패션의류 > 여성의류',
#  'level': 3,
#  'expsOrder': 1,
#  'parents': [{'cid': 0, 'name': '전체'},
#   {'cid': 50000000, 'name': '패션의류'},
#   {'cid': 50000167, 'name': '여성의류'}],
#  'childList': [],
#  'leaf': True,
#  'deleted': False,
#  'svcUse': True,
#  'sblogUse': True,
#  'fullPath': '패션의류 > 여성의류 > 니트/스웨터'}

# %%
for item in data:
    print(item['datetime'], item['ranks'][0]['rank'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [288], in <cell line: 1>()
#       1 for item in data:
# ----> 2     print(item, item['datetime'], item)
#
# TypeError: string indices must be integers

# %% [markdown]
# ### 다음 주식 일자별 주가 데이터 크롤링 연습

# %%
url = 'http://finance.daum.net/api/quote/A005930/days?symbolCode=A005930&page=2&perPage=10&pagination=true'

info = {
    'Referer': 'http://finance.daum.net/quotes/A005930?view=pc',
    'User-Agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Mobile Safari/537.36'
}

# %%
    #정보 요청
resp = requests.get(url, headers=info)

# %%
data = json.loads(resp.text)

# %%
df = pd.DataFrame(data['data'])
df
# Out:
#   symbolCode                 date  tradePrice tradeTime change  changePrice  \
# 0    A005930  2022-04-11 15:30:16     67900.0  15:30:16   RISE        100.0
# 1    A005930  2022-04-08 15:30:12     67800.0  15:30:12   FALL        200.0
# 2    A005930  2022-04-07 15:30:13     68000.0  15:30:13   FALL        500.0
# 3    A005930  2022-04-06 15:30:13     68500.0  15:30:13   FALL        700.0
# 4    A005930  2022-04-05 15:30:18     69200.0  15:30:18   FALL        100.0
# 5    A005930  2022-04-04 15:30:28     69300.0  15:30:28   RISE        200.0
# 6    A005930  2022-04-01 15:30:17     69100.0  15:30:17   FALL        500.0
# 7    A005930  2022-03-31 15:30:14     69600.0  15:30:14   FALL        300.0
# 8    A005930  2022-03-30 15:30:10     69900.0  15:30:10   FALL        300.0
# 9    A005930  2022-03-29 15:30:15     70200.0  15:30:15   RISE        500.0
#
#    changeRate  prevClosingPrice exchangeCountry  openingPrice  highPrice  \
# ...

# %% [markdown]
# ## 파파고 API

# %%
papago()
# Out:
# 번역이 필요한 한국어를 입력하세요 : 강의시작하겠습니다 카메라를 켜주시고 참석바랍니다.
# Let's begin the lecture. Please turn on the camera and attend.

# %% [markdown]
# ## 공공데이터 API

# %%
key='WiUh8jCCivl+c+pMYTVPFkW95df2UxKeaLf06Zg089WMN408H3g5G0bVG6ashqJmeCXDJNK8lxmhyr61XByWJQ=='
url = f'http://apis.data.go.kr/1790387/covid19CurrentStatusHospitalizations/covid19CurrentStatusHospitalizationsJson?serviceKey={key}'

# %%
resp = requests.get(url)

# %%
resp.text
# Out:
# '<OpenAPI_ServiceResponse>\n\t<cmmMsgHeader>\n\t\t<errMsg>SERVICE ERROR</errMsg>\n\t\t<returnAuthMsg>SERVICE_KEY_IS_NOT_REGISTERED_ERROR</returnAuthMsg>\n\t\t<returnReasonCode>30</returnReasonCode>\n\t</cmmMsgHeader>\n</OpenAPI_ServiceResponse>'

# %%
print(url)
# Out:
# http://apis.data.go.kr/1790387/covid19CurrentStatusHospitalizations/covid19CurrentStatusHospitalizationsJson?serviceKey=WiUh8jCCivl%2Bc%2BpMYTVPFkW95df2UxKeaLf06Zg089WMN408H3g5G0bVG6ashqJmeCXDJNK8lxmhyr61XByWJQ%3D%3D

# %%
# Out:
# 서울특별시 중구 퇴계로36길 10(필동2가 80-2)
# 서울특별시 중구 퇴계로34길 28(필동2가 84-1)
# 서울특별시 중구 퇴계로34길 28(필동2가 84-1)
# 서울특별시 중구 소월로 91(남대문로5가 471)
# 서울특별시 중구 장충동2가 산14-21
# 서울특별시 중구 남산공원길 125-72(예장동 산5-6)
# 서울특별시 중구 예장동 8-1
# 서울특별시 중구 예장동 8-1
# 서울특별시 중구 필동로1길 30(장충동2가 192-5)
# 서울특별시 중구 장충단로 72(장충동2가 201-6)
