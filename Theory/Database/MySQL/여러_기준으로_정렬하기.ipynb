# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT ANIMAL_ID, NAME, DATETIME
FROM ANIMAL_INS
ORDER BY NAME ASC, DATETIME DESC

# %% [markdown]
# ![image.png](data:image/png;base64,...)
