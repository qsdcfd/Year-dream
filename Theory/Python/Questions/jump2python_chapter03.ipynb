# %% [markdown]
# <a href="https://colab.research.google.com/github/qsdcfd/Year-dream/blob/TIL/Theory/Python/Questions/jump2python_chapter03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""shirt"""
# Out:
# 'shirt'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
i = 1
result = 0
while i < 1001:
    if i % 3 ==0:
        result += i
    i += 1
print(result)
# Out:
# 166833

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
i = 0


while True:
    i +=1
    if i > 5:
        break
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(101):
    print(i)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
list1 = [70,60,55,75,95,90,80,80,85,100]
total = 0
for A in list1:
    total += A
print(total / len(list1))
# Out:
# 79.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
numbers = [1,2,3,4,5]
result = [n * 2 for n in numbers if n % 2 ==1]
print(result)
# Out:
# [2, 6, 10]
