# %% [markdown]
# <a href="https://colab.research.google.com/github/qsdcfd/Year-dream/blob/TIL/Theory/Python/Questions/jump2python_chapter04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#함수
def is_odd(figure):

    if  figure % 2 == 0:
        return True
    else:
        return False

#람다

is_odds = lambda figure1: True if figure1 % 2 == 0 else False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def avg(*args):
    result = 0
    for i in args:
        result +=i
    return result / len(args)
avg(1,2)
# Out:
# 1.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
input1 = input("첫번째 숫자를 입력하세요:")
input2 = input("두번째 숫자를 입력하세요:")
total = int(input1) + int(input2)
print("두 수의 합은 %s 입니다" % total)
# Out:
# 첫번째 숫자를 입력하세요:3
# 두번째 숫자를 입력하세요:6
# 두 수의 합은 9 입니다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("you" "need" "python")
print("you"+"need"+"python")
print("you", "need", "python")
print("".join(["you", "need", "python"]))
# Out:
# youneedpython
# youneedpython
# you need python
# youneedpython

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
f1 = open("test.txt",'w')
f1.write("Life is too short")
f1.close()
f2 = open("test.txt", 'r')
print(f2.read())
f2.close()
# Out:
# Life is too short

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
user = input("저장하고 싶은 내용:")
f = open('test.txt','a')
f.write(user)
f.write('\n')
f.close()
# Out:
# 저장하고 싶은 내용:HI

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
f1 = open('test.txt','r')
body = f1.read()
f1.close()

body = body.replace('java', 'python')

f1 = open('test.txt', 'w')
f1.write(body)
f1.close()
