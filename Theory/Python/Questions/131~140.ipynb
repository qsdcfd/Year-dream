# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""사과, 귤, 수박"""
# Out:
# '사과, 귤, 수박'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
""" ### ### ###"""
# Out:
# ' ### ### ###'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
변수1 = "A"
print(변수1)

변수2 ='B'
print(변수2)

변수3 = 'C'
print(변수3)
# Out:
# A
# B
# C

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
변수1 = "A"
print("출력:", 변수1)

변수2 ='B'
print("출력:", 변수2)

변수3 = 'C'
print("출력:", 변수3)
# Out:
# 출력: A
# 출력: B
# 출력: C

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
변수1 = "A"
print("변환:", 변수1.lower())

변수2 ='B'
print("변환:", 변수2.lower())

변수3 = 'C'
print("변환:", 변수3.lower())
# Out:
# 변환: a
# 변환: b
# 변환: c

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for 변수 in [10,20,30]:
    print(변수)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for 변수 in [10,20,30]:
    print(변수)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for 변수 in [10,20,30]:
    print(변수)
    print("-------")
# Out:
# 10
# -------
# 20
# -------
# 30
# -------

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("++++")
for 변수 in [10,20,30]:
    print(변수)
# Out:
# ++++
# 10
# 20
# 30

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in [1,2,3,4]:
    print("-----")
# Out:
# -----
# -----
# -----
# -----
