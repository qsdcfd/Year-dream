# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""bool타입"""
# Out:
# 'bool타입'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""False"""
# Out:
# 'False'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""True"""
# Out:
# 'True'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""True"""
# Out:
# 'True'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""True"""
# Out:
# 'True'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""False"""
# Out:
# 'False'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
""" 조건식에서 False가 나오기 때문입니다. 즉, 지원하지 않는 연산자입니다."""
# Out:
# ' 조건식에서 False가 나오기 때문입니다'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""조건식에 맞지 않기에 else부분의 값이 나옵니다"""
# Out:
# '조건식에 맞지 않기에 else부분의 값이 나옵니다'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""1 2 4"""
# Out:
# '1 2 4'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""3 5"""
# Out:
# '3 5'
