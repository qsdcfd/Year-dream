# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q1

KOR = 80
ENG = 75
MATH = 55

score_Avg = (KOR+ENG+MATH)/3
print(score_Avg)

답지
a = 80
b = 75
c = 55
(a+b+c)/3 #70.0
# Out:
# 70.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q2
N = 13

if N % 2 !=0:
    print("홀수입니다.")
else:
    print("짝수입니다")

#답지
>>> 1 % 2
1
>>> 2 % 2
0
>>> 3 % 2
1
>>> 4 % 2
0
# Out:
# 홀수입니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q3
numbers = "881120-1068234"
yymmdd = numbers[:6]
figures = numbers[7:]

print("연월일:", yymmdd, "숫자:",figures)

#Q3-1
numbers = "881120-1068234"
print(numbers.split("-"))
#답지
pin = "881120-1068234"
yyyymmdd = pin[:6]
num = pin[7:]
print(yyyymmdd)  # 881120 출력
print(num)       # 1068234 출력
# Out:
# 연월일: 881120 숫자: 1068234

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q4
pin = "881120-1068234"
sex= pin[7]
print(sex)

#답지
pin = "881120-1068234"
print(pin[7])   # 1이면 남자, 2이면 여자
# Out:
# 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q5

a = "a:b:c:d"
b = a.replace(":","#")
print(b)

#답지
a = "a:b:c:d"
b = a.replace(":", "#")
print(b)
'a#b#c#d'
# Out:
# a#b#c#d

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q6

list1 = [1,3,5,4,2]
list1.sort(reverse=True)
print(list1)

#정답
a = [1, 3, 5, 4, 2]
a.sort( )
a.reverse( )
print(a)       # [5, 4, 3, 2, 1] 출력
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q7
list2 = ["Life","is","too","short"]
print(" ".join(list2))

#답지
a = ['Life', 'is', 'too', 'short']
result = " ".join(a)
print(result)
# Out:
# Life is too short

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q8
tuple1 = (1,2,3)
tuple2 = tuple1 + (4,)
print(tuple2)

#답지
a = (1, 2, 3)
a = a + (4,)
print(a)       # (1, 2, 3, 4) 출력
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q9
"3번입니다. 딕셔너리의 키는 불변값입니다."

#답지
"오류가 발생하는 이유는 딕셔너리의 키로는 변하는(mutable) 값을 사용할 수 없기 때문이다."
# Out:
# '오류가 발생하는 이유는 딕셔너리의 키로는 변하는(mutable) 값을 사용할 수 없기 때문이다.'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q10

a = {"A":90, "B":80, "C":70}
b = a.pop('B')

print(b)

#답지

a = {'A':90, 'B':80, 'C':70}
result = a.pop('B')
print(a)            # {'A':90, 'C':70} 출력
print(result)       # 80 출력
# Out:
# 80

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q11
a = [1, 1, 1, 2, 2, 3, 3, 3, 4, 4, 5]
b = set(a)
print(b)
#답지
a = [1, 1, 1, 2, 2, 3, 3, 3, 4, 4, 5]
aSet = set(a)     # a 리스트를 집합자료형으로 변환
b = list(aSet)    # 집합자료형을 리스트 자료형으로 다시 변환
print(b)          # [1,2,3,4,5] 출력
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Q12
a = b = [1, 2, 3]
a[1] = 4
print(b)

#내 답
"b는 a[1]=4로 인해서 4가 아닌 2가 나오는 리스트를 출력합니다"
#정답
"[1, 4, 3]이 출력된다. a와 b 변수는 모두 동일한 [1, 2, 3]이라는 리스트 객체를 가리키고 있기 때문이다."
# Out:
# [1, 4, 3]
