# %% [markdown]
# <a href="https://colab.research.google.com/github/qsdcfd/Year-dream/blob/TIL/Theory/Python/Questions/141~150.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
리스트 = [100, 200, 300]
for 돈 in 리스트:
    부가세 = 돈 + 10
    print(부가세)
# Out:
# 110
# 210
# 310

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
리스트 = ["김밥", "라면", "튀김"]

for 메뉴 in 리스트:
    print("오늘의 메뉴:", 메뉴)
# Out:
# 오늘의 메뉴: 김밥
# 오늘의 메뉴: 라면
# 오늘의 메뉴: 튀김

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
리스트 = ["SK하이닉스", "삼성전자", "LG전자"]

for 길이 in 리스트:
    print(len(길이))
# Out:
# 6
# 4
# 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
리스트 = ['dog', 'cat', 'parrot']

for 동물 in 리스트:
    print(동물, len(동물))
# Out:
# dog 3
# cat 3
# parrot 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
리스트 = ['dog', 'cat', 'parrot']

for 동물 in 리스트:
    print(동물[0])
# Out:
# d
# c
# p

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
리스트 = [1, 2, 3]

for 숫자 in 리스트:
    print(3,'x',숫자)
# Out:
# 3 x 1
# 3 x 2
# 3 x 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
리스트 = [1, 2, 3]

for 숫자 in 리스트:
    print(3,'x',숫자,'=',3 * 숫자)
# Out:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
리스트 = ["가", "나", "다", "라"]

for 글자 in 리스트[1:]:
    print(글자)
# Out:
# 나
# 다
# 라

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
리스트 = ["가", "나", "다", "라"]

for 글자 in 리스트[::2]:
    print(글자)
# Out:
# 가
# 다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
리스트 = ["가", "나", "다", "라"]

for 글자 in 리스트[::-1]:
    print(글자)
# Out:
# 라
# 다
# 나
# 가
