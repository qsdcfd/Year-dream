# %% [markdown]
# # 모듈 및 데이터 로딩 & 데이터 탐색

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import json
from pandas.io.json import json_normalize

# %%
data = pd.read_csv('ga.csv')

# %%
data.head()
# Out:
#   channelGrouping      date  \
# 0          Direct  20160902
# 1  Organic Search  20160902
# 2        Referral  20160902
# 3        Referral  20160902
# 4        Referral  20160902
#
#                                               device  fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...   6.194190e+18
# 1  {"browser": "Chrome", "browserVersion": "not a...   5.327170e+18
# 2  {"browser": "Chrome", "browserVersion": "not a...   8.885050e+18
# 3  {"browser": "Chrome", "browserVersion": "not a...   1.854680e+17
# 4  {"browser": "Chrome", "browserVersion": "not a...   3.244890e+18
#
#                                           geoNetwork  \
# 0  {"continent": "Americas", "subContinent": "Nor...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
#                         sessionId  socialEngagementType  \
# 0  6194193421514403509_1472843572  Not Socially Engaged
# 1  5327166854580374902_1472844906  Not Socially Engaged
# 2  8885051388942907862_1472827393  Not Socially Engaged
# 3  0185467632009737931_1472846398  Not Socially Engaged
# 4  3244885836845029978_1472824817  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "11", "pageviews": "11...
# 1  {"visits": "1", "hits": "11", "pageviews": "10...
# 2  {"visits": "1", "hits": "13", "pageviews": "11...
# 3  {"visits": "1", "hits": "13", "pageviews": "12...
# 4  {"visits": "1", "hits": "17", "pageviews": "14...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "(direct)"...  1472843572            1
# 1  {"campaign": "(not set)", "source": "google", ...  1472844906            3
# 2  {"referralPath": "/", "campaign": "(not set)",...  1472827393            7
# 3  {"referralPath": "/", "campaign": "(not set)",...  1472846398            6
# 4  {"referralPath": "/", "campaign": "(not set)",...  1472824817            4
#
#    visitStartTime
# 0      1472843572
# 1      1472844906
# 2      1472827393
# 3      1472846398
# 4      1472824817

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11515 entries, 0 to 11514
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   channelGrouping       11515 non-null  object
#  1   date                  11515 non-null  int64
#  2   device                11515 non-null  object
#  3   fullVisitorId         11515 non-null  float64
#  4   geoNetwork            11515 non-null  object
#  5   sessionId             11515 non-null  object
#  6   socialEngagementType  11515 non-null  object
#  7   totals                11515 non-null  object
#  8   trafficSource         11515 non-null  object
#  9   visitId               11515 non-null  int64
#  10  visitNumber           11515 non-null  int64
#  11  visitStartTime        11515 non-null  int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
data.head()
# Out:
#   channelGrouping      date  \
# 0          Direct  20160902
# 1  Organic Search  20160902
# 2        Referral  20160902
# 3        Referral  20160902
# 4        Referral  20160902
#
#                                               device  fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...   6.194190e+18
# 1  {"browser": "Chrome", "browserVersion": "not a...   5.327170e+18
# 2  {"browser": "Chrome", "browserVersion": "not a...   8.885050e+18
# 3  {"browser": "Chrome", "browserVersion": "not a...   1.854680e+17
# 4  {"browser": "Chrome", "browserVersion": "not a...   3.244890e+18
#
#                                           geoNetwork  \
# 0  {"continent": "Americas", "subContinent": "Nor...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
#                         sessionId  socialEngagementType  \
# 0  6194193421514403509_1472843572  Not Socially Engaged
# 1  5327166854580374902_1472844906  Not Socially Engaged
# 2  8885051388942907862_1472827393  Not Socially Engaged
# 3  0185467632009737931_1472846398  Not Socially Engaged
# 4  3244885836845029978_1472824817  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "11", "pageviews": "11...
# 1  {"visits": "1", "hits": "11", "pageviews": "10...
# 2  {"visits": "1", "hits": "13", "pageviews": "11...
# 3  {"visits": "1", "hits": "13", "pageviews": "12...
# 4  {"visits": "1", "hits": "17", "pageviews": "14...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"campaign": "(not set)", "source": "(direct)"...  1472843572            1
# 1  {"campaign": "(not set)", "source": "google", ...  1472844906            3
# 2  {"referralPath": "/", "campaign": "(not set)",...  1472827393            7
# 3  {"referralPath": "/", "campaign": "(not set)",...  1472846398            6
# 4  {"referralPath": "/", "campaign": "(not set)",...  1472824817            4
#
#    visitStartTime
# 0      1472843572
# 1      1472844906
# 2      1472827393
# 3      1472846398
# 4      1472824817

# %% [markdown]
# # json format 처리

# %%
#json jormat 컬럼 리스트로 정리
json_columns = ['device','geoNetwork','totals','trafficSource']

# %%
#json 형태로 파일 로드하기
data = pd.read_csv('ga.csv', converters = {column: json.loads for column in json_columns})

# %%
#로딩 결과 확인
data.iloc[0]['device']
# Out:
# {'browser': 'Chrome',
#  'browserVersion': 'not available in demo dataset',
#  'browserSize': 'not available in demo dataset',
#  'operatingSystem': 'Linux',
#  'operatingSystemVersion': 'not available in demo dataset',
#  'isMobile': False,
#  'mobileDeviceBranding': 'not available in demo dataset',
#  'mobileDeviceModel': 'not available in demo dataset',
#  'mobileInputSelector': 'not available in demo dataset',
#  'mobileDeviceInfo': 'not available in demo dataset',
#  'mobileDeviceMarketingName': 'not available in demo dataset',
#  'flashVersion': 'not available in demo dataset',
#  'language': 'not available in demo dataset',
#  'screenColors': 'not available in demo dataset',
#  'screenResolution': 'not available in demo dataset',
#  'deviceCategory': 'desktop'}

# %%
# json 데이터의 각 키값을 컬럼 형태로 변경
device = json_normalize(data['device'])
geoNetwork = json_normalize(data['geoNetwork'])
totals = json_normalize(data['totals'])
trafficSource = json_normalize(data['trafficSource'])
# Out:
# C:\Users\Sean\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#
# C:\Users\Sean\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Sean\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   after removing the cwd from sys.path.
# C:\Users\Sean\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """

# %%
# 기존 컬럼 아이디를 포함할 수 있도록 컬럼 이름 변경
device.columns = [f"{'device'}.{i}" for i in device.columns]
geoNetwork.columns = [f"{'geoNetwork'}.{i}" for i in geoNetwork.columns]
totals.columns = [f"{'totals'}.{i}" for i in totals.columns]
trafficSource.columns = [f"{'trafficSource'}.{i}" for i in trafficSource.columns]

# %%
# 기존 데이터와 통합
pd.concat([data, device, geoNetwork, totals, trafficSource], axis = 1).drop(json_columns, axis = 1)
# Out:
#       channelGrouping      date  fullVisitorId  \
# 0              Direct  20160902   6.194190e+18
# 1      Organic Search  20160902   5.327170e+18
# 2            Referral  20160902   8.885050e+18
# 3            Referral  20160902   1.854680e+17
# 4            Referral  20160902   3.244890e+18
# ...               ...       ...            ...
# 11510        Referral  20170104   6.849600e+18
# 11511        Referral  20170104   2.119870e+17
# 11512        Referral  20170104   9.981560e+18
# 11513          Direct  20170104   9.631260e+17
# 11514          Direct  20170104   9.771440e+18
#
#                             sessionId  socialEngagementType     visitId  \
# 0      6194193421514403509_1472843572  Not Socially Engaged  1472843572
# 1      5327166854580374902_1472844906  Not Socially Engaged  1472844906
# 2      8885051388942907862_1472827393  Not Socially Engaged  1472827393
# 3      0185467632009737931_1472846398  Not Socially Engaged  1472846398
# 4      3244885836845029978_1472824817  Not Socially Engaged  1472824817
# ...                               ...                   ...         ...
# 11510  6849604863010168468_1483566314  Not Socially Engaged  1483566314
# 11511  0211986650009953276_1483568879  Not Socially Engaged  1483568879
# 11512  9981562221973608723_1483576938  Not Socially Engaged  1483576938
# 11513   963126344221316701_1483552674  Not Socially Engaged  1483552674
# 11514  9771437221362506189_1483538997  Not Socially Engaged  1483538997
#
#        visitNumber  visitStartTime device.browser  \
# 0                1      1472843572         Chrome
# 1                3      1472844906         Chrome
# 2                7      1472827393         Chrome
# 3                6      1472846398         Chrome
# 4                4      1472824817         Chrome
# ...            ...             ...            ...
# 11510           10      1483566314         Chrome
# 11511            2      1483568879         Chrome
# 11512            1      1483576938         Chrome
# 11513            3      1483552674        Firefox
# 11514           12      1483538997         Chrome
#
#                device.browserVersion  ... trafficSource.isTrueDirect  \
# 0      not available in demo dataset  ...                       True
# 1      not available in demo dataset  ...                       True
# 2      not available in demo dataset  ...                       True
# 3      not available in demo dataset  ...                       True
# 4      not available in demo dataset  ...                       True
# ...                              ...  ...                        ...
# 11510  not available in demo dataset  ...                       True
# 11511  not available in demo dataset  ...                       True
# 11512  not available in demo dataset  ...                        NaN
# 11513  not available in demo dataset  ...                       True
# 11514  not available in demo dataset  ...                       True
#
#       trafficSource.adwordsClickInfo.criteriaParameters trafficSource.keyword  \
# 0                         not available in demo dataset                   NaN
# 1                         not available in demo dataset        (not provided)
# 2                         not available in demo dataset                   NaN
# 3                         not available in demo dataset                   NaN
# 4                         not available in demo dataset                   NaN
# ...                                                 ...                   ...
# 11510                     not available in demo dataset                   NaN
# 11511                     not available in demo dataset                   NaN
# 11512                     not available in demo dataset                   NaN
# 11513                     not available in demo dataset                   NaN
# 11514                     not available in demo dataset                   NaN
#
#        trafficSource.referralPath trafficSource.adContent  \
# 0                             NaN                     NaN
# 1                             NaN                     NaN
# 2                               /                     NaN
# 3                               /                     NaN
# 4                               /                     NaN
# ...                           ...                     ...
# 11510                           /                     NaN
# 11511                           /                     NaN
# 11512                           /                     NaN
# 11513                         NaN                     NaN
# 11514                         NaN                     NaN
#
#       trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
# ...                                   ...                                 ...
# 11510                                 NaN                                 NaN
# 11511                                 NaN                                 NaN
# 11512                                 NaN                                 NaN
# 11513                                 NaN                                 NaN
# 11514                                 NaN                                 NaN
#
#       trafficSource.adwordsClickInfo.gclId  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 11510                                  NaN
# 11511                                  NaN
# 11512                                  NaN
# 11513                                  NaN
# 11514                                  NaN
#
#       trafficSource.adwordsClickInfo.adNetworkType  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 11510                                          NaN
# 11511                                          NaN
# 11512                                          NaN
# 11513                                          NaN
# 11514                                          NaN
#
#       trafficSource.adwordsClickInfo.isVideoAd
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 11510                                      NaN
# 11511                                      NaN
# 11512                                      NaN
# 11513                                      NaN
# 11514                                      NaN
#
# [11515 rows x 53 columns]

# %%
# 위의 내용을 for loop를 사용하여 한번에 처리하기
for i in json_columns:
    json_df = json_normalize(data[i])
    json_df.columns = [f"{i}.{j}" for j in json_df.columns]
    data = pd.concat([data.drop(i, axis=1), json_df], axis = 1)
# Out:
# C:\Users\Sean\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
pd.set_option('display.max_columns', 100)

# %%
# 결과물 확인
data.head()
# Out:
#   channelGrouping      date  fullVisitorId                       sessionId  \
# 0          Direct  20160902   6.194190e+18  6194193421514403509_1472843572
# 1  Organic Search  20160902   5.327170e+18  5327166854580374902_1472844906
# 2        Referral  20160902   8.885050e+18  8885051388942907862_1472827393
# 3        Referral  20160902   1.854680e+17  0185467632009737931_1472846398
# 4        Referral  20160902   3.244890e+18  3244885836845029978_1472824817
#
#    socialEngagementType     visitId  visitNumber  visitStartTime  \
# 0  Not Socially Engaged  1472843572            1      1472843572
# 1  Not Socially Engaged  1472844906            3      1472844906
# 2  Not Socially Engaged  1472827393            7      1472827393
# 3  Not Socially Engaged  1472846398            6      1472846398
# 4  Not Socially Engaged  1472824817            4      1472824817
#
#   device.browser          device.browserVersion  \
# 0         Chrome  not available in demo dataset
# 1         Chrome  not available in demo dataset
# 2         Chrome  not available in demo dataset
# 3         Chrome  not available in demo dataset
# 4         Chrome  not available in demo dataset
#
#               device.browserSize device.operatingSystem  \
# 0  not available in demo dataset                  Linux
# 1  not available in demo dataset              Macintosh
# 2  not available in demo dataset                  Linux
# 3  not available in demo dataset                Windows
# 4  not available in demo dataset              Macintosh
#
#    device.operatingSystemVersion  device.isMobile  \
# 0  not available in demo dataset            False
# 1  not available in demo dataset            False
# 2  not available in demo dataset            False
# 3  not available in demo dataset            False
# 4  not available in demo dataset            False
#
#      device.mobileDeviceBranding       device.mobileDeviceModel  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#       device.mobileInputSelector        device.mobileDeviceInfo  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   device.mobileDeviceMarketingName            device.flashVersion  \
# 0    not available in demo dataset  not available in demo dataset
# 1    not available in demo dataset  not available in demo dataset
# 2    not available in demo dataset  not available in demo dataset
# 3    not available in demo dataset  not available in demo dataset
# 4    not available in demo dataset  not available in demo dataset
#
#                  device.language            device.screenColors  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#          device.screenResolution device.deviceCategory geoNetwork.continent  \
# 0  not available in demo dataset               desktop             Americas
# 1  not available in demo dataset               desktop             Americas
# 2  not available in demo dataset               desktop             Americas
# 3  not available in demo dataset               desktop             Americas
# 4  not available in demo dataset               desktop             Americas
#
#   geoNetwork.subContinent geoNetwork.country              geoNetwork.region  \
# 0        Northern America      United States                       Michigan
# 1        Northern America      United States                       New York
# 2        Northern America      United States                       New York
# 3        Northern America      United States                     California
# 4        Northern America      United States  not available in demo dataset
#
#                     geoNetwork.metro                geoNetwork.city  \
# 0                         Detroit MI                      Ann Arbor
# 1                        New York NY                       New York
# 2                        New York NY                       New York
# 3  San Francisco-Oakland-San Jose CA                  Mountain View
# 4      not available in demo dataset  not available in demo dataset
#
#                geoNetwork.cityId geoNetwork.networkDomain  \
# 0  not available in demo dataset                (not set)
# 1  not available in demo dataset                (not set)
# 2  not available in demo dataset                (not set)
# 3  not available in demo dataset                (not set)
# 4  not available in demo dataset                (not set)
#
#              geoNetwork.latitude           geoNetwork.longitude  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#       geoNetwork.networkLocation totals.visits totals.hits totals.pageviews  \
# 0  not available in demo dataset             1          11               11
# 1  not available in demo dataset             1          11               10
# 2  not available in demo dataset             1          13               11
# 3  not available in demo dataset             1          13               12
# 4  not available in demo dataset             1          17               14
#
#   totals.transactionRevenue totals.newVisits trafficSource.campaign  \
# 0                  37860000                1              (not set)
# 1                 306670000              NaN              (not set)
# 2                  68030000              NaN              (not set)
# 3                  26250000              NaN              (not set)
# 4                 574150000              NaN              (not set)
#
#   trafficSource.source trafficSource.medium trafficSource.isTrueDirect  \
# 0             (direct)               (none)                       True
# 1               google              organic                       True
# 2  mall.googleplex.com             referral                       True
# 3  mall.googleplex.com             referral                       True
# 4  mall.googleplex.com             referral                       True
#
#   trafficSource.adwordsClickInfo.criteriaParameters trafficSource.keyword  \
# 0                     not available in demo dataset                   NaN
# 1                     not available in demo dataset        (not provided)
# 2                     not available in demo dataset                   NaN
# 3                     not available in demo dataset                   NaN
# 4                     not available in demo dataset                   NaN
#
#   trafficSource.referralPath trafficSource.adContent  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                          /                     NaN
# 3                          /                     NaN
# 4                          /                     NaN
#
#   trafficSource.adwordsClickInfo.page trafficSource.adwordsClickInfo.slot  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#   trafficSource.adwordsClickInfo.gclId  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   trafficSource.adwordsClickInfo.adNetworkType  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   trafficSource.adwordsClickInfo.isVideoAd
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11515 entries, 0 to 11514
# Data columns (total 53 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   channelGrouping                                    11515 non-null  object
#  1   date                                               11515 non-null  int64
#  2   fullVisitorId                                      11515 non-null  float64
#  3   sessionId                                          11515 non-null  object
#  4   socialEngagementType                               11515 non-null  object
#  5   visitId                                            11515 non-null  int64
#  6   visitNumber                                        11515 non-null  int64
#  7   visitStartTime                                     11515 non-null  int64
#  8   device.browser                                     11515 non-null  object
#  9   device.browserVersion                              11515 non-null  object
#  10  device.browserSize                                 11515 non-null  object
#  11  device.operatingSystem                             11515 non-null  object
#  12  device.operatingSystemVersion                      11515 non-null  object
#  13  device.isMobile                                    11515 non-null  bool
#  14  device.mobileDeviceBranding                        11515 non-null  object
#  15  device.mobileDeviceModel                           11515 non-null  object
#  16  device.mobileInputSelector                         11515 non-null  object
#  17  device.mobileDeviceInfo                            11515 non-null  object
#  18  device.mobileDeviceMarketingName                   11515 non-null  object
#  19  device.flashVersion                                11515 non-null  object
#  20  device.language                                    11515 non-null  object
#  21  device.screenColors                                11515 non-null  object
#  22  device.screenResolution                            11515 non-null  object
#  23  device.deviceCategory                              11515 non-null  object
#  24  geoNetwork.continent                               11515 non-null  object
#  25  geoNetwork.subContinent                            11515 non-null  object
#  26  geoNetwork.country                                 11515 non-null  object
#  27  geoNetwork.region                                  11515 non-null  object
#  28  geoNetwork.metro                                   11515 non-null  object
#  29  geoNetwork.city                                    11515 non-null  object
#  30  geoNetwork.cityId                                  11515 non-null  object
#  31  geoNetwork.networkDomain                           11515 non-null  object
#  32  geoNetwork.latitude                                11515 non-null  object
#  33  geoNetwork.longitude                               11515 non-null  object
#  34  geoNetwork.networkLocation                         11515 non-null  object
#  35  totals.visits                                      11515 non-null  object
#  36  totals.hits                                        11515 non-null  object
#  37  totals.pageviews                                   11515 non-null  object
#  38  totals.transactionRevenue                          11515 non-null  object
#  39  totals.newVisits                                   4465 non-null   object
#  40  trafficSource.campaign                             11515 non-null  object
#  41  trafficSource.source                               11515 non-null  object
#  42  trafficSource.medium                               11515 non-null  object
#  43  trafficSource.isTrueDirect                         7004 non-null   object
#  44  trafficSource.adwordsClickInfo.criteriaParameters  11515 non-null  object
#  45  trafficSource.keyword                              3871 non-null   object
#  46  trafficSource.referralPath                         5415 non-null   object
#  47  trafficSource.adContent                            143 non-null    object
#  48  trafficSource.adwordsClickInfo.page                454 non-null    object
#  49  trafficSource.adwordsClickInfo.slot                454 non-null    object
#  50  trafficSource.adwordsClickInfo.gclId               456 non-null    object
#  51  trafficSource.adwordsClickInfo.adNetworkType       454 non-null    object
#  52  trafficSource.adwordsClickInfo.isVideoAd           454 non-null    object
# dtypes: bool(1), float64(1), int64(4), object(47)
# memory usage: 4.6+ MB

# %% [markdown]
# # object(text)로 인식 된 데이터를 숫자형태로 변경

# %%
totals = ['totals.visits','totals.hits','totals.pageviews','totals.transactionRevenue','totals.newVisits']

# %%
for i in totals:
    data[i] = pd.to_numeric(data[i])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11515 entries, 0 to 11514
# Data columns (total 53 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   channelGrouping                                    11515 non-null  object
#  1   date                                               11515 non-null  int64
#  2   fullVisitorId                                      11515 non-null  float64
#  3   sessionId                                          11515 non-null  object
#  4   socialEngagementType                               11515 non-null  object
#  5   visitId                                            11515 non-null  int64
#  6   visitNumber                                        11515 non-null  int64
#  7   visitStartTime                                     11515 non-null  int64
#  8   device.browser                                     11515 non-null  object
#  9   device.browserVersion                              11515 non-null  object
#  10  device.browserSize                                 11515 non-null  object
#  11  device.operatingSystem                             11515 non-null  object
#  12  device.operatingSystemVersion                      11515 non-null  object
#  13  device.isMobile                                    11515 non-null  bool
#  14  device.mobileDeviceBranding                        11515 non-null  object
#  15  device.mobileDeviceModel                           11515 non-null  object
#  16  device.mobileInputSelector                         11515 non-null  object
#  17  device.mobileDeviceInfo                            11515 non-null  object
#  18  device.mobileDeviceMarketingName                   11515 non-null  object
#  19  device.flashVersion                                11515 non-null  object
#  20  device.language                                    11515 non-null  object
#  21  device.screenColors                                11515 non-null  object
#  22  device.screenResolution                            11515 non-null  object
#  23  device.deviceCategory                              11515 non-null  object
#  24  geoNetwork.continent                               11515 non-null  object
#  25  geoNetwork.subContinent                            11515 non-null  object
#  26  geoNetwork.country                                 11515 non-null  object
#  27  geoNetwork.region                                  11515 non-null  object
#  28  geoNetwork.metro                                   11515 non-null  object
#  29  geoNetwork.city                                    11515 non-null  object
#  30  geoNetwork.cityId                                  11515 non-null  object
#  31  geoNetwork.networkDomain                           11515 non-null  object
#  32  geoNetwork.latitude                                11515 non-null  object
#  33  geoNetwork.longitude                               11515 non-null  object
#  34  geoNetwork.networkLocation                         11515 non-null  object
#  35  totals.visits                                      11515 non-null  int64
#  36  totals.hits                                        11515 non-null  int64
#  37  totals.pageviews                                   11515 non-null  int64
#  38  totals.transactionRevenue                          11515 non-null  int64
#  39  totals.newVisits                                   4465 non-null   float64
#  40  trafficSource.campaign                             11515 non-null  object
#  41  trafficSource.source                               11515 non-null  object
#  42  trafficSource.medium                               11515 non-null  object
#  43  trafficSource.isTrueDirect                         7004 non-null   object
#  44  trafficSource.adwordsClickInfo.criteriaParameters  11515 non-null  object
#  45  trafficSource.keyword                              3871 non-null   object
#  46  trafficSource.referralPath                         5415 non-null   object
#  47  trafficSource.adContent                            143 non-null    object
#  48  trafficSource.adwordsClickInfo.page                454 non-null    object
#  49  trafficSource.adwordsClickInfo.slot                454 non-null    object
#  50  trafficSource.adwordsClickInfo.gclId               456 non-null    object
#  51  trafficSource.adwordsClickInfo.adNetworkType       454 non-null    object
#  52  trafficSource.adwordsClickInfo.isVideoAd           454 non-null    object
# dtypes: bool(1), float64(2), int64(8), object(42)
# memory usage: 4.6+ MB

# %%
data.describe()
# Out:
#                date  fullVisitorId       visitId   visitNumber  \
# count  1.151500e+04   1.151500e+04  1.151500e+04  11515.000000
# mean   2.016622e+07   4.503303e+18  1.485876e+09      4.083196
# std    4.687452e+03   3.062080e+18  9.308961e+06     12.508556
# min    2.016080e+07   2.131310e+14  1.470046e+09      1.000000
# 25%    2.016110e+07   1.639590e+18  1.478054e+09      1.000000
# 50%    2.017013e+07   4.377180e+18  1.485554e+09      2.000000
# 75%    2.017050e+07   7.184570e+18  1.493948e+09      4.000000
# max    2.017080e+07   9.999000e+18  1.501652e+09    315.000000
#
#        visitStartTime  totals.visits   totals.hits  totals.pageviews  \
# count    1.151500e+04        11515.0  11515.000000      11515.000000
# mean     1.485876e+09            1.0     36.274251         28.330439
# std      9.308963e+06            0.0     30.269294         21.727555
# min      1.470046e+09            1.0      2.000000          2.000000
# 25%      1.478054e+09            1.0     19.000000         16.000000
# 50%      1.485554e+09            1.0     28.000000         23.000000
# 75%      1.493948e+09            1.0     44.000000         34.000000
# max      1.501652e+09            1.0    500.000000        469.000000
#
#        totals.transactionRevenue  totals.newVisits
# count               1.151500e+04            4465.0
# mean                1.337448e+08               1.0
# std                 4.482852e+08               0.0
# min                 1.000000e+04               1.0
# 25%                 2.493000e+07               1.0
# 50%                 4.945000e+07               1.0
# 75%                 1.076550e+08               1.0
# max                 2.312950e+10               1.0

# %% [markdown]
# # Target 값에 로그 취하기

# %%
# 기존 target갑의 distplot
sns.distplot(data['totals.transactionRevenue'])
# Out:
# C:\Users\Sean\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='totals.transactionRevenue', ylabel='Density'>

# %%
# log 씌워준 target값의 distplot
sns.distplot(np.log(data['totals.transactionRevenue']))
# Out:
# C:\Users\Sean\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='totals.transactionRevenue', ylabel='Density'>

# %%
# log 취한 값으로 업데이트
data['totals.transactionRevenue'] = np.log(data['totals.transactionRevenue'])

# %% [markdown]
# # 불필요한 데이터 제거

# %%
drop_list = ['fullVisitorId','sessionId','visitId','visitStartTime']

# %%
data.drop(drop_list, axis=1, inplace = True)

# %% [markdown]
# # Missing Value 처리하기

# %%
# 90% 이상 누락된 컬럼 모아서 drop 시키기
na_list = data.isna().mean()[data.isna().mean()  > 0.9].index

data.drop(na_list, axis=1, inplace = True)

# %%
# 남은 Missing Value 컬럼 확인
data.isna().mean()[data.isna().mean() > 0]
# Out:
# totals.newVisits              0.612245
# trafficSource.isTrueDirect    0.391750
# trafficSource.keyword         0.663830
# trafficSource.referralPath    0.529744
# dtype: float64

# %%
# 한종류의 value만 있으므로 제거
data['totals.newVisits'].value_counts()
# Out:
# 1.0    4465
# Name: totals.newVisits, dtype: int64

# %%
data.drop('totals.newVisits', axis=1, inplace = True)

# %%
# 한종류의 value만 있으므로 제거
data['trafficSource.isTrueDirect'].value_counts()
# Out:
# True    7004
# Name: trafficSource.isTrueDirect, dtype: int64

# %%
data.drop('trafficSource.isTrueDirect', axis=1, inplace = True)

# %%
data['trafficSource.keyword'].value_counts()
# Out:
# (not provided)                             3387
# 6qEhsCssdK0z36ri                            261
# google merchandise store                     59
# 1hZbAqLCbjwfgOH7                             56
# Google Merchandise                           45
# (Remarketing/Content targeting)               9
# +Google +Merchandise                          7
# 1X4Me6ZKNV0zg-jV                              6
# +Google +Swag                                 3
# +Google +Gear                                 3
# google store                                  3
# GOOGLE MERCHANDISE                            2
# +google +merchandise +store                   2
# youtube merch                                 2
# +google +store                                2
# google store merchandise                      2
# category_l1==166                              2
# google apparel store                          2
# google stickers                               2
# google men's hoodie pullover                  1
# YouTube Merchandise                           1
# google shirt                                  1
# +google +stores                               1
# google items for sale                         1
# +google +coffee +mug                          1
# google merch                                  1
# (automatic matching)                          1
# google merchandise                            1
# you tube trucker cap google merchandise       1
# +google+tshirts                               1
# youtube merchandise store                     1
# googlemerchandisestore                        1
# Youtube merchandise store                     1
# googlesupport                                 1
# +google +merch                                1
# Name: trafficSource.keyword, dtype: int64

# %%
# 'unknown'으로 Missing Value 채우기
data['trafficSource.keyword'] = data['trafficSource.keyword'].fillna('unknown')

# %%
# 불필요한 정보로 판단되어 제거
data['trafficSource.referralPath'].value_counts()
# Out:
# /                                                                                                                                                                                  5151
# /mail/u/0/                                                                                                                                                                           55
# /a/google.com/forum/                                                                                                                                                                 35
# /google-merchandise-store                                                                                                                                                            22
# /offer/2145                                                                                                                                                                          18
# /deal/-ds-sign-up-for-google-merchandise-store-emails-for-special-coup-c179                                                                                                          17
# /a/google.com/googletopia/discounts-deals-and-free-stuff/alphabet-google-discounts                                                                                                   12
# /a/google.com/google-merchandise-store/on-site-store/mountain-view-store                                                                                                             11
# /a/google.com/google-merchandise-store/on-site-store                                                                                                                                  9
# /l.php                                                                                                                                                                                8
# /yt/about/                                                                                                                                                                            8
# /od/Things-To-Do-in-Silicon-Valley/fl/How-To-Visit-the-Googleplex-the-Google-Head-Office-in-Mountain-View.htm                                                                         6
# /2015/03/11/google-merch-store-new-url/                                                                                                                                               6
# /permissions/using-the-logo.html                                                                                                                                                      5
# /Rewards/Products/Details.aspx                                                                                                                                                        4
# /forum/                                                                                                                                                                               3
# /neo/launch                                                                                                                                                                           3
# /mail/u/1/                                                                                                                                                                            3
# /corp/google.com/google-merchandise-store/faqs                                                                                                                                        2
# /external-link.jspa                                                                                                                                                                   2
# /QpXvjwMv6t                                                                                                                                                                           2
# /a/google.com/google-merchandise-store/home/on-site-store                                                                                                                             2
# /mail/ca/u/0/                                                                                                                                                                         2
# /a/google.com/nestlabs/nestling/nestling                                                                                                                                              2
# /HBtw4R2RL5                                                                                                                                                                           1
# /neo/b/message                                                                                                                                                                        1
# /webmail/en-us/tablet                                                                                                                                                                 1
# /watch                                                                                                                                                                                1
# /_/scs/mail-static/_/js/k=gmail.main.en.sXDiEpUnPe0.O/m=m_i,t,it/am=nhGvDGD-3_uDcQ3DgK701brz33u-Xyo_e7nH_ycDROlVoP_N_h_A_4H-tI0C/rt=h/d=1/rs=AHGWq9Bm-1qj1hhkb8cG9EpeilyYgWjoxA       1
# /yt/about/copyright/                                                                                                                                                                  1
# /deal/-ds-1655-youtube-player-tshirt-unisex-vs-1780-list                                                                                                                              1
# /neo/rd                                                                                                                                                                               1
# /IUI6ugD07C                                                                                                                                                                           1
# /site/northcountycomputer/                                                                                                                                                            1
# /r/chromeos/comments/39boco/looking_for_chrome_sticker/                                                                                                                               1
# /Where-can-I-buy-a-stuffed-Go-language-gopher-mascot-online                                                                                                                           1
# /KtfjgWJtWs                                                                                                                                                                           1
# /document/d/1uELQ97D_yoYkVD_C7Jqc2i1R2gQfn9H0KjfVbu3m-kU/edit                                                                                                                         1
# /search/GGmain.jhtml                                                                                                                                                                  1
# /calendar/r/week/2017/7/8                                                                                                                                                             1
# /community/partners/local-sites/japanese/gsuite/marketing/google-store                                                                                                                1
# /a/google.com/aa-noogler/getting-started/training-schedule                                                                                                                            1
# /2610273/projects/12161610/todos/250267685                                                                                                                                            1
# /a/google.com/google-merchandise-store/newsite/on-site-store/mountain-view-store                                                                                                      1
# /_/scs/mail-static/_/js/k=gmail.main.en.yASPeSEQ5YQ.O/m=m_i,t/am=OotXDrD_7_3BuIZhQFf6at3573--_VR26Oce_58IiCKvAv3___8A_w_ko20U/rt=h/d=1/rs=AHGWq9DZAa74rKvcihAYhdWoJ70MBwYmVA          1
# /Lw3hzUjkK9                                                                                                                                                                           1
# /yt/about/en-GB/                                                                                                                                                                      1
# /Google/shop.axd/ValidateLogin                                                                                                                                                        1
# /a/google.com/another-attempt-google-merchandise-store/mountain-view-on-site-merchandise-store                                                                                        1
# /xud9jul6em                                                                                                                                                                           1
# /photos/google-dog-toy-21237.html                                                                                                                                                     1
# Name: trafficSource.referralPath, dtype: int64

# %%
data.drop('trafficSource.referralPath', axis=1, inplace = True)

# %%
data.isna().mean()
# Out:
# channelGrouping                                      0.0
# date                                                 0.0
# socialEngagementType                                 0.0
# visitNumber                                          0.0
# device.browser                                       0.0
# device.browserVersion                                0.0
# device.browserSize                                   0.0
# device.operatingSystem                               0.0
# device.operatingSystemVersion                        0.0
# device.isMobile                                      0.0
# device.mobileDeviceBranding                          0.0
# device.mobileDeviceModel                             0.0
# device.mobileInputSelector                           0.0
# device.mobileDeviceInfo                              0.0
# device.mobileDeviceMarketingName                     0.0
# device.flashVersion                                  0.0
# device.language                                      0.0
# device.screenColors                                  0.0
# device.screenResolution                              0.0
# device.deviceCategory                                0.0
# geoNetwork.continent                                 0.0
# geoNetwork.subContinent                              0.0
# geoNetwork.country                                   0.0
# geoNetwork.region                                    0.0
# geoNetwork.metro                                     0.0
# geoNetwork.city                                      0.0
# geoNetwork.cityId                                    0.0
# geoNetwork.networkDomain                             0.0
# geoNetwork.latitude                                  0.0
# geoNetwork.longitude                                 0.0
# geoNetwork.networkLocation                           0.0
# totals.visits                                        0.0
# totals.hits                                          0.0
# totals.pageviews                                     0.0
# totals.transactionRevenue                            0.0
# trafficSource.campaign                               0.0
# trafficSource.source                                 0.0
# trafficSource.medium                                 0.0
# trafficSource.adwordsClickInfo.criteriaParameters    0.0
# trafficSource.keyword                                0.0
# dtype: float64

# %% [markdown]
# # 카테고리 컬럼 처리하기

# %%
# 각 카테고리 컬럼의 unique value 갯수 확인하기
for i in data.columns:
    if data[i].dtype == 'O':
        print(i, data[i].nunique())
# Out:
# channelGrouping 8
# socialEngagementType 1
# device.browser 9
# device.browserVersion 1
# device.browserSize 1
# device.operatingSystem 7
# device.operatingSystemVersion 1
# device.mobileDeviceBranding 1
# device.mobileDeviceModel 1
# device.mobileInputSelector 1
# device.mobileDeviceInfo 1
# device.mobileDeviceMarketingName 1
# device.flashVersion 1
# device.language 1
# device.screenColors 1
# device.screenResolution 1
# device.deviceCategory 3
# geoNetwork.continent 6
# geoNetwork.subContinent 19
# geoNetwork.country 69
# geoNetwork.region 79
# geoNetwork.metro 46
# geoNetwork.city 134
# geoNetwork.cityId 1
# geoNetwork.networkDomain 732
# geoNetwork.latitude 1
# geoNetwork.longitude 1
# geoNetwork.networkLocation 1
# trafficSource.campaign 7
# trafficSource.source 44
# trafficSource.medium 7
# trafficSource.adwordsClickInfo.criteriaParameters 1
# trafficSource.keyword 36

# %%
# 위에서 확인한 정보를 데이터프레임 형태로 저장

count = pd.DataFrame(columns=['count'])

for i in data.columns:
    if data[i].dtype == 'O':
        count.loc[i] = data[i].nunique()

# %%
count
# Out:
#                                                   count
# channelGrouping                                       8
# socialEngagementType                                  1
# device.browser                                        9
# device.browserVersion                                 1
# device.browserSize                                    1
# device.operatingSystem                                7
# device.operatingSystemVersion                         1
# device.mobileDeviceBranding                           1
# device.mobileDeviceModel                              1
# device.mobileInputSelector                            1
# device.mobileDeviceInfo                               1
# device.mobileDeviceMarketingName                      1
# device.flashVersion                                   1
# device.language                                       1
# device.screenColors                                   1
# device.screenResolution                               1
# device.deviceCategory                                 3
# geoNetwork.continent                                  6
# geoNetwork.subContinent                              19
# geoNetwork.country                                   69
# geoNetwork.region                                    79
# geoNetwork.metro                                     46
# geoNetwork.city                                     134
# geoNetwork.cityId                                     1
# geoNetwork.networkDomain                            732
# geoNetwork.latitude                                   1
# geoNetwork.longitude                                  1
# geoNetwork.networkLocation                            1
# trafficSource.campaign                                7
# trafficSource.source                                 44
# trafficSource.medium                                  7
# trafficSource.adwordsClickInfo.criteriaParameters     1
# trafficSource.keyword                                36

# %%
# value가 한종류인 컬럼 모아서 drop
value_one = count[count['count'] == 1].index
data.drop(value_one, axis=1, inplace = True)

# %%
# value가 70개 이상은 컬럼 모아서 drop
value_large = count[count['count'] > 70].index
data.drop(value_large, axis=1, inplace = True)

# %%
data.head()
# Out:
#   channelGrouping      date  visitNumber device.browser  \
# 0          Direct  20160902            1         Chrome
# 1  Organic Search  20160902            3         Chrome
# 2        Referral  20160902            7         Chrome
# 3        Referral  20160902            6         Chrome
# 4        Referral  20160902            4         Chrome
#
#   device.operatingSystem  device.isMobile device.deviceCategory  \
# 0                  Linux            False               desktop
# 1              Macintosh            False               desktop
# 2                  Linux            False               desktop
# 3                Windows            False               desktop
# 4              Macintosh            False               desktop
#
#   geoNetwork.continent geoNetwork.subContinent geoNetwork.country  \
# 0             Americas        Northern America      United States
# 1             Americas        Northern America      United States
# 2             Americas        Northern America      United States
# 3             Americas        Northern America      United States
# 4             Americas        Northern America      United States
#
#                     geoNetwork.metro  totals.visits  totals.hits  \
# 0                         Detroit MI              1           11
# 1                        New York NY              1           11
# 2                        New York NY              1           13
# 3  San Francisco-Oakland-San Jose CA              1           13
# 4      not available in demo dataset              1           17
#
#    totals.pageviews  totals.transactionRevenue trafficSource.campaign  \
# 0                11                  17.449406              (not set)
# 1                10                  19.541283              (not set)
# 2                11                  18.035459              (not set)
# 3                12                  17.083177              (not set)
# 4                14                  20.168401              (not set)
#
#   trafficSource.source trafficSource.medium trafficSource.keyword
# 0             (direct)               (none)               unknown
# 1               google              organic        (not provided)
# 2  mall.googleplex.com             referral               unknown
# 3  mall.googleplex.com             referral               unknown
# 4  mall.googleplex.com             referral               unknown

# %%
# Get dummy를 사용하기 위해 카테고리 컬럼들 리스트로 정리
obj_list = []

for i in data.columns:
    if data[i].dtype == 'O':
        obj_list.append(i)

# %%
obj_list
# Out:
# ['channelGrouping',
#  'device.browser',
#  'device.operatingSystem',
#  'device.deviceCategory',
#  'geoNetwork.continent',
#  'geoNetwork.subContinent',
#  'geoNetwork.country',
#  'geoNetwork.metro',
#  'trafficSource.campaign',
#  'trafficSource.source',
#  'trafficSource.medium',
#  'trafficSource.keyword']

# %%
data = pd.get_dummies(data, columns = obj_list, drop_first=True)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop('totals.transactionRevenue', axis = 1)
y = data['totals.transactionRevenue']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.2, random_state=100)

# %% [markdown]
# # Random Forest 모델링 및 예측

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(max_depth = 10, n_estimators = 1000)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=1000)

# %%
pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, pred) ** 0.5
# Out:
# 1.0534328708549394

# %%
sns.scatterplot(y_test, pred)
# Out:
# C:\Users\Sean\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='totals.transactionRevenue'>
